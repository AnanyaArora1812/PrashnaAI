# %%
project_name = "PrashnaAI"
project_type = "Domain-Specific Question Answering"

print("Project:", project_name)
print("Type:", project_type)

# %%
project_name = "PrashnaAI"
duration_months = 2
is_llm_project = True
technologies = ["Python", "PyTorch", "LLaMA"]

print(type(project_name))
print(type(duration_months))
print(type(is_llm_project))
print(type(technologies))
